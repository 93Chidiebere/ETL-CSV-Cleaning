# %%
import os
import pandas as pd

# %%
Path = "C:/Users/DELL/OneDrive/Documents/ETL/DataSource"

# %% [markdown]
# ### 1. Data Extraction

# %%
# Data Extraction
def data_extract(data_dir = Path):
    dfs = []
    for file in os.listdir(data_dir):
        if file.endswith(".csv"):
            path = os.path.join(data_dir, file)
            
            # Read csv file
            df = pd.read_csv(path)

            # Extract Category from filename
            category = file.split("-")[2] if "-" in file else "unknown"
            df["category"] = category
            df["source_file"] = file
            dfs.append(df)
            
    return dfs

dfs = data_extract()
print(f"extracted {len(dfs)} files")
# Out:
# extracted 21 files

# %% [markdown]
# ### 2. Data Transformation

# %% [markdown]
# > Before we begin transforming, let's randomly look at just 3 of the 21 datasets

# %%
# Display 3 of the 21 files
file1 = "C:/Users/DELL/OneDrive/Documents/ETL/DataSource/us-shein-appliances-3987.csv"
file2 = "C:/Users/DELL/OneDrive/Documents/ETL/DataSource/us-shein-automotive-4110.csv"
file3 = "C:/Users/DELL/OneDrive/Documents/ETL/DataSource/us-shein-baby_and_maternity-4433.csv"

# Load the 3 files
df1 = pd.read_csv(file1, low_memory = False)
df2 = pd.read_csv(file2, low_memory = False)
df3 = pd.read_csv(file3, low_memory = False)

# Display shape (rows and columns)
print("appliances", df1.shape)
print("automotive", df2.shape)
print("baby_and_maternity", df3.shape)
# Out:
# appliances (3986, 8)
# automotive (4109, 6)
# baby_and_maternity (4432, 7)

# %% [markdown]
# #### Displaying first 2 rows

# %%
print("Sample from appliances:")
print(df1.head(2))

print("Sample from automotive:")
print(df2.head(2))
# Out:
# Sample from appliances:
#                               goods-title-link--jump  \
# 0  1pc Rechargeable Deep Tissue Muscle Handheld M...
# 1                      1pc Portable Hanging Neck Fan
#
#                          goods-title-link--jump href       rank-title  \
# 0  https://us.shein.com/1pc-Rechargeable-Deep-Tis...  #1 Best Sellers
# 1  https://us.shein.com/1pc-Portable-Hanging-Neck...  #4 Best Sellers
#
#                         rank-sub  price discount selling_proposition  \
# 0                  in Give Gifts  $2.03     -22%                 NaN
# 1  in Top rated in Portable Fans  $6.48     -20%                 NaN
#
#   goods-title-link
# 0              NaN
# 1              NaN
# Sample from automotive:
#                               goods-title-link--jump  \
# 0  1pc/2PCS Car Cup Coaster, Bling Cup Holder Ins...
# 1  Jesus The Way Truth Life Sticker For Car Windo...
#
#                          goods-title-link--jump href  price discount  \
# 0  https://us.shein.com/1pc-2PCS-Car-Cup-Coaster-...  $0.68     -60%
# 1  https://us.shein.com/Jesus-The-Way-Truth-Life-...  $1.60     -20%
#
#   selling_proposition goods-title-link
# 0                 NaN              NaN
# 1  500+ sold recently              NaN

# %%
# Checking for missing values

print("Missing values from appliances:")
print(df1.isnull().sum())
print()
print("Missing values from automotive:")
print(df2.isnull().sum())
# Out:
# Missing values from appliances:
# goods-title-link--jump         3946
# goods-title-link--jump href    3946
# rank-title                     3427
# rank-sub                       3427
# price                             0
# discount                       1527
# selling_proposition            2625
# goods-title-link                 40
# dtype: int64
#
# Missing values from automotive:
# goods-title-link--jump         4069
# goods-title-link--jump href    4069
# price                             0
# discount                       2736
# selling_proposition            1235
# goods-title-link                 40
# dtype: int64

# %% [markdown]
# ## Findings
# ### Duplicate Columns
# >> The columns "goods-title-link--jump", "goods-title-link--jump href" and "goods-title-link" all contain the same information per row.
# ### Missing Values
# >>The rows with missing values in "goods-title-link--jump" have its correct values in "goods-title-link" and vice versa. The "goods-title-link--jump" column will be filled up, and then the other two will be deleted for all the datasets.
# ### Miscellaneous
# >> The column titles will be standardized and made uniform across all datasets

# %%
def clean_df(df):
    # Standardize column names
    df.columns = [c.strip().lower().replace(" ", (_)) for c in df.columns]
    
    # if both columns exist, merge them
    if "goods-title-link--jump" in df.columns and "goods-title-link" in df.columns:
        df["goods-title-link--jump"] = df["goods-title-link--jump"].fillna(df["goods-title-link"])
        
    elif "goods-title-link" in df.columns and "goods-title-link--jump" not in df.columns:
        # Rename "goods-title-link" to "goods-title-link--jump" for consistency
        df = df.rename(columns = {"goods-title-link":"goods-title-link--jump"})
        
    # Drop any complete empty columns
    df = df.dropna(axis = 1, how = "all")
    # Drop "goods-title-link--jump href"
    df = df.drop(columns = ["goods-title-link--jump href", "goods-title-link"], errors = "ignore")
        
    return df

# %%
# Print missing values
def missing_values(df, name):
    print(f"missing values from {name}:")
    print(df.isnull().sum())
    print("\n" + "="*50 + "\n")
    
    # Loop through the 21 csv files, clean and print missing values
    
all_dataframes = {}

files = [f for f in os.listdir(Path) if f.endswith(".csv")]
print(f"Found {len(files)} CSV files\n")
for idx, file in enumerate(files, start = 1):
    file_path = os.path.join(Path, file)

    # Load CSV
    df = pd.read_csv(file_path, low_memory = False)
            
    # Clean the CSV
    df_clean = clean_df(df)
            
    # Save in dictionary for later SQL loading
    name = os.path.splitext(file)[0] # [0] filename without extension  
    all_dataframes[name] = df_clean
            
    # Print missing values report
    print(f"processing files {idx}/{len(files)}: {file}")
    missing_values(df_clean, name)
# Out:
# Found 21 CSV files
#
# processing files 1/21: us-shein-appliances-3987.csv
# missing values from us-shein-appliances-3987:
# goods-title-link--jump           0
# goods-title-link--jumphref    3946
# rank-title                    3427
# rank-sub                      3427
# price                            0
# discount                      1527
# selling_proposition           2625
# dtype: int64
#
# ==================================================
#
# processing files 2/21: us-shein-automotive-4110.csv
# missing values from us-shein-automotive-4110:
# goods-title-link--jump           0
# goods-title-link--jumphref    4069
# price                            0
# discount                      2736
# selling_proposition           1235
# dtype: int64
#
# ==================================================
#
# processing files 3/21: us-shein-baby_and_maternity-4433.csv
# missing values from us-shein-baby_and_maternity-4433:
# goods-title-link--jump           0
# goods-title-link--jumphref    4394
# selling_proposition            931
# price                            0
# discount                      1633
# color-count                   3341
# dtype: int64
#
# ==================================================
#
# processing files 4/21: us-shein-bags_and_luggage-4299.csv
# missing values from us-shein-bags_and_luggage-4299:
# color-count                   2506
# goods-title-link--jump           0
# goods-title-link--jumphref    4259
# selling_proposition            646
# price                            0
# discount                       145
# rank-title                    3893
# rank-sub                      3893
# dtype: int64
#
# ==================================================
#
# processing files 5/21: us-shein-beauty_and_health-4267.csv
# missing values from us-shein-beauty_and_health-4267:
# goods-title-link--jump           0
# goods-title-link--jumphref    4227
# selling_proposition           1009
# price                            0
# discount                       282
# color-count                   3060
# rank-title                    3428
# rank-sub                      3428
# dtype: int64
#
# ==================================================
#
# processing files 6/21: us-shein-curve-2849.csv
# missing values from us-shein-curve-2849:
# color-count                   1478
# goods-title-link--jump           1
# goods-title-link--jumphref    2809
# rank-title                    2316
# rank-sub                      2316
# price                            1
# discount                        80
# selling_proposition            555
# dtype: int64
#
# ==================================================
#
# processing files 7/21: us-shein-electronics-4395.csv
# missing values from us-shein-electronics-4395:
# goods-title-link--jump           0
# goods-title-link--jumphref    4356
# rank-title                    3647
# rank-sub                      3647
# price                            0
# discount                      2869
# selling_proposition           1227
# color-count                   3256
# dtype: int64
#
# ==================================================
#
# processing files 8/21: us-shein-home_and_kitchen-3719.csv
# missing values from us-shein-home_and_kitchen-3719:
# goods-title-link--jump       0
# rank-title                2630
# rank-sub                  2630
# price                        0
# selling_proposition       1258
# discount                  2125
# dtype: int64
#
# ==================================================
#
# processing files 9/21: us-shein-home_textile-3883.csv
# missing values from us-shein-home_textile-3883:
# goods-title-link--jump           0
# goods-title-link--jumphref    3843
# rank-title                    3357
# rank-sub                      3357
# price                            0
# color-count                   2705
# selling_proposition           1085
# discount                      2413
# dtype: int64
#
# ==================================================
#
# processing files 10/21: us-shein-jewelry_and_accessories-3548.csv
# missing values from us-shein-jewelry_and_accessories-3548:
# goods-title-link--jump           0
# goods-title-link--jumphref    3508
# rank-title                    2831
# rank-sub                      2831
# price                            0
# selling_proposition            811
# discount                      1621
# dtype: int64
#
# ==================================================
#
# processing files 11/21: us-shein-kids-4314.csv
# missing values from us-shein-kids-4314:
# color-count                   2947
# goods-title-link--jump           0
# goods-title-link--jumphref    4274
# rank-title                    3530
# rank-sub                      3530
# price                            0
# discount                        51
# selling_proposition            878
# dtype: int64
#
# ==================================================
#
# processing files 12/21: us-shein-mens_clothes-1891.csv
# missing values from us-shein-mens_clothes-1891:
# color-count                749
# goods-title-link--jump       1
# selling_proposition        613
# price                        1
# discount                    30
# rank-title                1330
# rank-sub                  1330
# dtype: int64
#
# ==================================================
#
# processing files 13/21: us-shein-office_and_school_supplies-4233.csv
# missing values from us-shein-office_and_school_supplies-4233:
# goods-title-link--jump           0
# goods-title-link--jumphref    4193
# rank-title                    3573
# rank-sub                      3573
# price                            0
# discount                      2582
# selling_proposition           1274
# dtype: int64
#
# ==================================================
#
# processing files 14/21: us-shein-pet_supplies-4083.csv
# missing values from us-shein-pet_supplies-4083:
# goods-title-link--jump           0
# goods-title-link--jumphref    4042
# selling_proposition           1619
# price                            0
# blackfridaybelts-bgsrc        1862
# blackfridaybelts-content      1862
# rank-title                    3537
# rank-sub                      3537
# discount                      1112
# color-count                   3601
# dtype: int64
#
# ==================================================
#
# processing files 15/21: us-shein-shoes-4381.csv
# missing values from us-shein-shoes-4381:
# color-count                   2200
# goods-title-link--jump           0
# goods-title-link--jumphref    4341
# rank-title                    3106
# rank-sub                      3106
# price                            0
# discount                       131
# selling_proposition           1581
# dtype: int64
#
# ==================================================
#
# processing files 16/21: us-shein-sports_and_outdoors-3853.csv
# missing values from us-shein-sports_and_outdoors-3853:
# color-count                   2637
# blackfridaybelts-bgsrc        2281
# blackfridaybelts-content      2281
# goods-title-link--jump           0
# goods-title-link--jumphref    3813
# rank-title                    2666
# rank-sub                      2666
# price                            0
# discount                       627
# selling_proposition           1359
# dtype: int64
#
# ==================================================
#
# processing files 17/21: us-shein-swimwear-3761.csv
# missing values from us-shein-swimwear-3761:
# color-count                   1854
# goods-title-link--jump           0
# goods-title-link--jumphref    3720
# price                            0
# rank-title                    3166
# rank-sub                      3166
# discount                       219
# dtype: int64
#
# ==================================================
#
# processing files 18/21: us-shein-tools_and_home_improvement-3903.csv
# missing values from us-shein-tools_and_home_improvement-3903:
# goods-title-link--jump           0
# goods-title-link--jumphref    3864
# rank-title                    3082
# rank-sub                      3082
# price                            0
# selling_proposition           1563
# discount                      2045
# dtype: int64
#
# ==================================================
#
# processing files 19/21: us-shein-toys_and_games-3577.csv
# missing values from us-shein-toys_and_games-3577:
# rank-title                2993
# rank-sub                  2993
# price                        0
# selling_proposition       1273
# discount                  2066
# goods-title-link--jump      12
# dtype: int64
#
# ==================================================
#
# processing files 20/21: us-shein-underwear_and_sleepwear-4019.csv
# missing values from us-shein-underwear_and_sleepwear-4019:
# goods-title-link--jump           0
# goods-title-link--jumphref    3979
# selling_proposition           1272
# price                            0
# discount                       967
# rank-title                    2884
# rank-sub                      2884
# color-count                   2753
# dtype: int64
#
# ==================================================
# processing files 21/21: us-shein-womens_clothing-4620.csv
# missing values from us-shein-womens_clothing-4620:
# product-locatelabels-imgsrc     997
# color-count                    2204
# goods-title-link--jump            0
# rank-title                     3563
# rank-sub                       3563
# price                             0
# discount                       1867
# selling_proposition            1167
# dtype: int64
#
# ==================================================
